# %%
import pandas as pd
from langchain_core.documents import Document

# %%
# def dataconveter():
#     Nepal_imports_data=pd.read_csv("D:\\Customs Clearance_chatbot\\data\\nepal_imports_1000.csv")

#     data=Nepal_imports_data[["Product_ID","Product_Category","Product_Name","CIF_Value_USD","Customs_Duty_Rate_pct","Customs_Duty_USD,VAT_pct","VAT_USD","Total_Landed_Cost_USD"]]

#     product_list = []

# %%
Nepal_imports_data_1=pd.read_csv("D:\\Customs Clearance_chatbot\\data1\\nepal_imports_1000_New_updated.csv")
Nepal_imports_data_1.head()
# Out:
#   Product_ID                                Product_Category  Product_Name  \
# 0  NPIMP0001  Agricultural / Primary Products (India origin)          Rice
# 1  NPIMP0002                          Electronics (consumer)        Laptop
# 2  NPIMP0003              Machinery / Basic industrial goods      CNC Part
# 3  NPIMP0004  Agricultural / Primary Products (India origin)    Vegetables
# 4  NPIMP0005            Luxury Items (watches / accessories)  Luxury Watch
#
#    CIF_Value_USD  Customs_Duty_Rate_pct  Customs_Duty_USD  VAT_pct  VAT_USD  \
# 0         190.19                   3.75              7.13       13    25.65
# 1        1217.38                  19.64            239.09       13   189.34
# 2        1201.98                   6.56             78.85       13   166.51
# 3         173.37                   0.58              1.01       13    22.67
# 4        3554.96                  68.03           2418.44       13   776.54
#
# ...

# %%
# Print all columns
print(Nepal_imports_data_1.columns.tolist())
# Out:
# ['Product_ID', 'Product_Category', 'Product_Name', 'CIF_Value_USD', 'Customs_Duty_Rate_pct', 'Customs_Duty_USD', 'VAT_pct', 'VAT_USD', 'Total_Landed_Cost_USD', 'Notes', 'product_tax', 'product_price']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for index, row in data.iterrows():
    # Construct an object with all required attributes

 obj = {
        'product_name': row['product_title'],
        'review': row['review'],
        'Product_ID': row['Product_ID'],
        'Product_Category': row['Product_Category'],
        'Product_Name': row['Product_Name'],
        'CIF_Value_USD': row['CIF_Value_USD'],
        'Customs_Duty_Rate_pct': row['Customs_Duty_Rate_pct'],
        'Customs_Duty_USD': row['Customs_Duty_USD'],
        'VAT_pct': row['VAT_pct'],
        'VAT_USD': row['VAT_USD'],
        'Total_Landed_Cost_USD': row['Total_Landed_Cost_USD']
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for index, row in data.iterrows():
#       2     # Construct an object with all required attributes
#       4  obj = {
#       5         'product_name': row['product_title'],
#       6         'review': row['review'],
#    (...)
#      15         'Total_Landed_Cost_USD': row['Total_Landed_Cost_USD']
#      16     }
#
# NameError: name 'data' is not defined
